# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = pd.read_excel('Datos de Facturación_Limpio.xlsx')
data1.head()
data2 = pd.read_excel('Gastos y costos_2020_Limpio.xlsx')
data2.head
data3 = pd.read_excel('Gastos y costos_2021_Limpio.xlsx')
data3.head
data4 = pd.read_excel('Gastos y costos_2022_Limpio.xlsx')
data4.head
data5 = pd.read_excel('Gastos y costos_2023_Limpio.xlsx')
data5.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0      FECHA                   FOLIO  \
# 0              0 2021-01-01  0001010100750847116902
# 1              1 2021-01-01  0001010100752163714102
# 2              2 2021-01-01                   19788
# 3              3 2021-01-01                  211781
# 4              4 2021-01-01                  211782
# ...          ...        ...                     ...
# 3030        3030 2021-12-01                  127043
# 3031        3031 2021-12-01                   11740
# 3032        3032 2021-12-01              1092957089
# 3033        3033 2021-12-01                  747826
# 3034        3034 2021-12-01                 1227374
#
#                                       UUID           RFC  \
# 0     71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B  BNM840515VB1
# 1     B8AEDE83-CC76-404C-A611-6B5A87BA561F  BNM840515VB1
# 2     19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7  ESI9612311E7
# 3     EAB26414-DD9A-4E8F-9F5C-05FE24D98E48  BLE1512082R9
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895 entries, 0 to 10894
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     10895 non-null  int64
#  1   CVE_DOC        10895 non-null  object
#  2   CVE_CLPV       10895 non-null  int64
#  3   STATUS         10895 non-null  object
#  4   CVE_VEND       10895 non-null  float64
#  5   FECHAELAB      10895 non-null  datetime64[ns]
#  6   FECHA_DOC      10895 non-null  datetime64[ns]
#  7   FECHA_ENT      10895 non-null  object
#  8   FECHA_VEN      10895 non-null  datetime64[ns]
#  9   FECHA_CANCELA  10895 non-null  datetime64[ns]
#  10  CAN_TOT        10895 non-null  float64
#  11  DES_TOT        10895 non-null  float64
#  12  DES_FIN        10895 non-null  int64
# dtypes: datetime64[ns](4), float64(3), int64(3), object(3)
# memory usage: 1.1+ MB

# %%
data1.isnull().sum()
# Out:
# Unnamed: 0       0
# CVE_DOC          0
# CVE_CLPV         0
# STATUS           0
# CVE_VEND         0
# FECHAELAB        0
# FECHA_DOC        0
# FECHA_ENT        0
# FECHA_VEN        0
# FECHA_CANCELA    0
# CAN_TOT          0
# DES_TOT          0
# DES_FIN          0
# dtype: int64

# %%
fig = plt.figure(figsize = (15,8))
data1cuantitativos.plot(kind = 'box', vert = False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
data1cuantitativos = data1.iloc[ : , [2,4,10,11,12]]
data1cuantitativos
# Out:
#        CVE_CLPV  CVE_VEND  CAN_TOT  DES_TOT  DES_FIN
# 0          2465       1.0  3980.00      0.0        0
# 1          3926       1.0  1550.00      0.0        0
# 2          3926       1.0  1550.00      0.0        0
# 3          3927       1.0  1550.00      0.0        0
# 4          3928       2.0  2435.44      0.0        0
# ...         ...       ...      ...      ...      ...
# 10890     14814       2.0  3272.00      0.0        0
# 10891     14815       2.0   504.15      0.0        0
# 10892     14816       2.0   275.68      0.0        0
# 10893     14817       2.0   129.30      0.0        0
# 10894     14818       2.0   517.20      0.0        0
#
# [10895 rows x 5 columns]

# %%
data1cuantitativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895 entries, 0 to 10894
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CVE_CLPV  10895 non-null  float64
#  1   CVE_VEND  10895 non-null  float64
#  2   CAN_TOT   10895 non-null  float64
#  3   DES_TOT   10895 non-null  float64
#  4   DES_FIN   10895 non-null  float64
# dtypes: float64(5)
# memory usage: 425.7 KB

# %%
data1cuantitativos['CVE_CLPV'] = data1cuantitativos['CVE_CLPV'].astype(float)
data1cuantitativos['DES_FIN'] = data1cuantitativos['DES_FIN'].astype(float)
# Out:
# <ipython-input-24-6da7701a11c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1cuantitativos['CVE_CLPV'] = data1cuantitativos['CVE_CLPV'].astype(float)
# <ipython-input-24-6da7701a11c5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1cuantitativos['DES_FIN'] = data1cuantitativos['DES_FIN'].astype(float)

# %%
y = data1cuantitativos
limite_superior = y.mean() + 3*y.std()
limite_inferior = y.mean() - 3*y.std()
print("Limite superior permitido", limite_superior)
print("Limite inferior permitido", limite_inferior)
# Out:
# Limite superior permitido CVE_CLPV    18807.434432
# CVE_VEND        5.809966
# CAN_TOT     40074.135271
# DES_TOT      1326.077661
# DES_FIN         0.000000
# dtype: float64
# Limite inferior permitido CVE_CLPV      -65.702078
# CVE_VEND       -1.084276
# CAN_TOT    -31037.684244
# DES_TOT     -1289.561077
# DES_FIN         0.000000
# dtype: float64

# %%
data33 = data1cuantitativos[(y<=limite_superior)&(y>=limite_inferior)]
data33
# Out:
#        CVE_CLPV  CVE_VEND  CAN_TOT  DES_TOT  DES_FIN
# 0        2465.0       1.0  3980.00      0.0      0.0
# 1        3926.0       1.0  1550.00      0.0      0.0
# 2        3926.0       1.0  1550.00      0.0      0.0
# 3        3927.0       1.0  1550.00      0.0      0.0
# 4        3928.0       2.0  2435.44      0.0      0.0
# ...         ...       ...      ...      ...      ...
# 10890   14814.0       2.0  3272.00      0.0      0.0
# 10891   14815.0       2.0   504.15      0.0      0.0
# 10892   14816.0       2.0   275.68      0.0      0.0
# 10893   14817.0       2.0   129.30      0.0      0.0
# 10894   14818.0       2.0   517.20      0.0      0.0
#
# [10895 rows x 5 columns]

# %%
data_clean1 = data33.copy()
data_clean1 = data_clean1.fillna(round(data33.mean(),1))
data_clean1
# Out:
#        CVE_CLPV  CVE_VEND  CAN_TOT  DES_TOT  DES_FIN
# 0        2465.0       1.0  3980.00      0.0      0.0
# 1        3926.0       1.0  1550.00      0.0      0.0
# 2        3926.0       1.0  1550.00      0.0      0.0
# 3        3927.0       1.0  1550.00      0.0      0.0
# 4        3928.0       2.0  2435.44      0.0      0.0
# ...         ...       ...      ...      ...      ...
# 10890   14814.0       2.0  3272.00      0.0      0.0
# 10891   14815.0       2.0   504.15      0.0      0.0
# 10892   14816.0       2.0   275.68      0.0      0.0
# 10893   14817.0       2.0   129.30      0.0      0.0
# 10894   14818.0       2.0   517.20      0.0      0.0
#
# [10895 rows x 5 columns]

# %%
fig = plt.figure(figsize = (15,8))
data_clean1.plot(kind = 'box', vert = False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
Anexo1 = data1[['CVE_DOC','CVE_CLPV','STATUS','CVE_VEND','FECHAELAB','FECHA_DOC', 'FECHA_ENT','FECHA_VEN','FECHA_CANCELA']]
datos_limpios1 = pd.concat([Anexo1, data_clean1], axis = 1)
datos_limpios1
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414      2465      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415      3926      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416      3926      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417      3927      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418      3928      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...       ...    ...       ...                     ...        ...
# 10890  F40306     14814      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307     14815      E       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892  F40307     14816      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309     14817      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310     14818      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %%
#Guardamos el archivo como excel
datos_limpios1.to_excel("datos_limpios1 - Datos de Facturación.xlsx")

# %% [markdown]
# Gastos y Costos 2020

# %%
data2cuantitativos = data2.iloc[ : , [9,10,11,12,13,14,19]]
data2cuantitativos
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  Columna1
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28  14051.72
# 1     1.0    490.00    78.40      0.0      0.0    568.40      0.00
# 2     1.0    195.00    31.20      0.0      0.0    226.20      0.00
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33      0.00
# 4     1.0      0.00   519.80      0.0      0.0      0.00      0.00
# ...   ...       ...      ...      ...      ...       ...       ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00      0.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37      0.00
# 3339  1.0    163.79    26.21      0.0      0.0    190.00      0.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00      0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29      0.00
#
# [3342 rows x 7 columns]

# %%
data2cuantitativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TC        3342 non-null   float64
#  1   IMPORTE   3342 non-null   float64
#  2   IVA       3342 non-null   float64
#  3   RET ISR   3342 non-null   float64
#  4   RET IVA   3342 non-null   float64
#  5   TOTAL MX  3342 non-null   float64
#  6   Columna1  3342 non-null   float64
# dtypes: float64(7)
# memory usage: 182.9 KB

# %%
fig = plt.figure(figsize = (15,8))
data2cuantitativos.plot(kind = 'box', vert = False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
y = data2cuantitativos
limite_superior = y.mean() + 3*y.std()
limite_inferior = y.mean() - 3*y.std()
print("Limite superior permitido", limite_superior)
print("Limite inferior permitido", limite_inferior)
# Out:
# Limite superior permitido TC              4.251032
# IMPORTE     25167.992859
# IVA          4563.165637
# RET ISR       667.271992
# RET IVA       958.239955
# TOTAL MX    28488.002843
# Columna1    14626.999268
# dtype: float64
# Limite inferior permitido TC             -2.117814
# IMPORTE    -18869.298785
# IVA         -3523.520012
# RET ISR      -627.750813
# RET IVA      -839.215179
# TOTAL MX   -21455.655297
# Columna1   -14171.411134
# dtype: float64

# %%
data3_1 = data2cuantitativos[(y<=limite_superior)&(y>=limite_inferior)]
data3_1
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  Columna1
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28  14051.72
# 1     1.0    490.00    78.40      0.0      0.0    568.40      0.00
# 2     1.0    195.00    31.20      0.0      0.0    226.20      0.00
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33      0.00
# 4     1.0      0.00   519.80      0.0      0.0      0.00      0.00
# ...   ...       ...      ...      ...      ...       ...       ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00      0.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37      0.00
# 3339  1.0    163.79    26.21      0.0      0.0    190.00      0.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00      0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29      0.00
#
# [3342 rows x 7 columns]

# %%
data_clean2 = data3_1.copy()
data_clean2 = data_clean2.fillna(round(data3_1.mean(),1))
data_clean2
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  Columna1
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28  14051.72
# 1     1.0    490.00    78.40      0.0      0.0    568.40      0.00
# 2     1.0    195.00    31.20      0.0      0.0    226.20      0.00
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33      0.00
# 4     1.0      0.00   519.80      0.0      0.0      0.00      0.00
# ...   ...       ...      ...      ...      ...       ...       ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00      0.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37      0.00
# 3339  1.0    163.79    26.21      0.0      0.0    190.00      0.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00      0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29      0.00
#
# [3342 rows x 7 columns]

# %%
fig = plt.figure(figsize = (15,8))
data_clean2.plot(kind = 'box', vert = False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
Anexo2 = data2[['FECHA','FOLIO','UUID','RFC','PROVEEDOR','TIPO GASTO', 'DESCRIPCION','POLIZA','TIPO','STATUS']]
datos_limpios2 = pd.concat([Anexo2, data_clean2], axis = 1)
datos_limpios2
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
#Guardamos el archivo como excel
datos_limpios2.to_excel("datos_limpios2 - Gastos y costos 2020.xlsx")

# %% [markdown]
# Gastos y costos 2021

# %%
data3cuantitativos = data3.iloc[ : , [9,10,11,12,13,14,15]]
data3cuantitativos
# Out:
#        TC   IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0    490.00   78.40      0.0      0.0    568.40     568.40
# 1     1.0    345.00   55.20      0.0      0.0    400.20     400.20
# 2     1.0   3447.41  551.59      0.0      0.0   3999.00    3999.00
# 3     1.0   5551.38  888.22      0.0      0.0   6439.60    6439.60
# 4     1.0   5551.98  888.32      0.0      0.0   6440.30    6440.30
# ...   ...       ...     ...      ...      ...       ...        ...
# 3030  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3031  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3032  1.0  22826.46  705.58      0.0      0.0  23532.04   23532.04
# 3033  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3034  1.0  15656.15    0.00      0.0      0.0  15656.15   15656.15
#
# [3035 rows x 7 columns]

# %%
data3cuantitativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TC         3035 non-null   float64
#  1   IMPORTE    3035 non-null   float64
#  2   IVA        3035 non-null   float64
#  3   RET ISR    3035 non-null   float64
#  4   RET IVA    3035 non-null   float64
#  5   TOTAL MX   3035 non-null   float64
#  6   TOTAL SAT  3035 non-null   float64
# dtypes: float64(7)
# memory usage: 166.1 KB

# %%
fig = plt.figure(figsize = (15,8))
data3cuantitativos.plot(kind = 'box', vert = False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
y = data3cuantitativos
limite_superior = y.mean() + 3*y.std()
limite_inferior = y.mean() - 3*y.std()
print("Limite superior permitido", limite_superior)
print("Limite inferior permitido", limite_inferior)
# Out:
# Limite superior permitido TC               6.286851
# IMPORTE      36154.569820
# IVA           5464.876801
# RET ISR        900.150092
# RET IVA       1200.884906
# TOTAL MX     40680.462408
# TOTAL SAT    40671.985064
# dtype: float64
# Limite inferior permitido TC              -3.981398
# IMPORTE     -27625.812771
# IVA          -4276.811367
# RET ISR       -833.428945
# RET IVA      -1053.848939
# TOTAL MX    -31176.694132
# TOTAL SAT   -31129.503410
# dtype: float64

# %%
data3_2 = data3cuantitativos[(y<=limite_superior)&(y>=limite_inferior)]
data3_2
# Out:
#        TC   IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0    490.00   78.40      0.0      0.0    568.40     568.40
# 1     1.0    345.00   55.20      0.0      0.0    400.20     400.20
# 2     1.0   3447.41  551.59      0.0      0.0   3999.00    3999.00
# 3     1.0   5551.38  888.22      0.0      0.0   6439.60    6439.60
# 4     1.0   5551.98  888.32      0.0      0.0   6440.30    6440.30
# ...   ...       ...     ...      ...      ...       ...        ...
# 3030  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3031  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3032  1.0  22826.46  705.58      0.0      0.0  23532.04   23532.04
# 3033  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3034  1.0  15656.15    0.00      0.0      0.0  15656.15   15656.15
#
# [3035 rows x 7 columns]

# %%
data_clean3 = data3_2.copy()
data_clean3 = data_clean3.fillna(round(data3_2.mean(),1))
data_clean3
# Out:
#        TC   IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0    490.00   78.40      0.0      0.0    568.40     568.40
# 1     1.0    345.00   55.20      0.0      0.0    400.20     400.20
# 2     1.0   3447.41  551.59      0.0      0.0   3999.00    3999.00
# 3     1.0   5551.38  888.22      0.0      0.0   6439.60    6439.60
# 4     1.0   5551.98  888.32      0.0      0.0   6440.30    6440.30
# ...   ...       ...     ...      ...      ...       ...        ...
# 3030  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3031  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3032  1.0  22826.46  705.58      0.0      0.0  23532.04   23532.04
# 3033  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3034  1.0  15656.15    0.00      0.0      0.0  15656.15   15656.15
#
# [3035 rows x 7 columns]

# %%
fig = plt.figure(figsize = (15,8))
data_clean3.plot(kind = 'box', vert = False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
Anexo3 = data3[['FECHA','FOLIO','UUID','RFC','PROVEEDOR','TIPO GASTO', 'DESCRIPCION','MP','TIPO','STATUS']]
datos_limpios3 = pd.concat([Anexo3, data_clean3], axis = 1)
datos_limpios3
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
#Guardamos el archivo como excel
datos_limpios3.to_excel("datos_limpios3 - Gastos y costos 2021.xlsx")

# %% [markdown]
# Gastos y costos 2022

# %%
data4cuantitativos = data4.iloc[ : , [9,10,11,12,13,14,15]]
data4cuantitativos
# Out:
#        TC   IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0    490.00   78.40      0.0      0.0    568.40     568.40
# 1     1.0    345.00   55.20      0.0      0.0    400.20     400.20
# 2     1.0   3447.41  551.59      0.0      0.0   3999.00    3999.00
# 3     1.0   5551.38  888.22      0.0      0.0   6439.60    6439.60
# 4     1.0   5551.98  888.32      0.0      0.0   6440.30    6440.30
# ...   ...       ...     ...      ...      ...       ...        ...
# 3030  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3031  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3032  1.0  22826.46  705.58      0.0      0.0  23532.04   23532.04
# 3033  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3034  1.0  15656.15    0.00      0.0      0.0  15656.15   15656.15
#
# [3035 rows x 7 columns]

# %%
data4cuantitativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TC         3035 non-null   float64
#  1   IMPORTE    3035 non-null   float64
#  2   IVA        3035 non-null   float64
#  3   RET ISR    3035 non-null   float64
#  4   RET IVA    3035 non-null   float64
#  5   TOTAL MX   3035 non-null   float64
#  6   TOTAL SAT  3035 non-null   float64
# dtypes: float64(7)
# memory usage: 166.1 KB

# %%
fig = plt.figure(figsize = (15,8))
data4cuantitativos.plot(kind = 'box', vert = False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
y = data4cuantitativos

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

limite_superior_iqr = percentile75 + 1.5*iqr
limite_inferior_iqr = percentile25 - 1.5*iqr
print("Limite superior permitido", limite_superior_iqr)
print("Limite inferior permitido", limite_inferior_iqr)
# Out:
# Limite superior permitido TC               1.0000
# IMPORTE      10127.7125
# IVA           1381.4750
# RET ISR          0.0000
# RET IVA          0.0000
# TOTAL MX     11580.2750
# TOTAL SAT    11456.0225
# dtype: float64
# Limite inferior permitido TC              1.0000
# IMPORTE     -6076.6275
# IVA          -828.8850
# RET ISR         0.0000
# RET IVA         0.0000
# TOTAL MX    -6948.1650
# TOTAL SAT   -6818.3175
# dtype: float64

# %%
data3_3 = data4cuantitativos[(y<=limite_superior)&(y>=limite_inferior)]
data3_3
# Out:
#        TC   IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0    490.00   78.40      0.0      0.0    568.40     568.40
# 1     1.0    345.00   55.20      0.0      0.0    400.20     400.20
# 2     1.0   3447.41  551.59      0.0      0.0   3999.00    3999.00
# 3     1.0   5551.38  888.22      0.0      0.0   6439.60    6439.60
# 4     1.0   5551.98  888.32      0.0      0.0   6440.30    6440.30
# ...   ...       ...     ...      ...      ...       ...        ...
# 3030  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3031  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3032  1.0  22826.46  705.58      0.0      0.0  23532.04   23532.04
# 3033  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3034  1.0  15656.15    0.00      0.0      0.0  15656.15   15656.15
#
# [3035 rows x 7 columns]

# %%
data_clean4 = data3_3.copy()
data_clean4 = data_clean4.fillna(round(data3_3.mean(),1))
data_clean4
# Out:
#        TC   IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0    490.00   78.40      0.0      0.0    568.40     568.40
# 1     1.0    345.00   55.20      0.0      0.0    400.20     400.20
# 2     1.0   3447.41  551.59      0.0      0.0   3999.00    3999.00
# 3     1.0   5551.38  888.22      0.0      0.0   6439.60    6439.60
# 4     1.0   5551.98  888.32      0.0      0.0   6440.30    6440.30
# ...   ...       ...     ...      ...      ...       ...        ...
# 3030  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3031  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3032  1.0  22826.46  705.58      0.0      0.0  23532.04   23532.04
# 3033  1.0      0.00    0.00      0.0      0.0      0.00       0.00
# 3034  1.0  15656.15    0.00      0.0      0.0  15656.15   15656.15
#
# [3035 rows x 7 columns]

# %%
Anexo4 = data4[['FECHA','FOLIO','UUID','RFC','PROVEEDOR','TIPO GASTO', 'DESCRIPCION','MP','TIPO','STATUS']]
datos_limpios4 = pd.concat([Anexo4, data_clean4], axis = 1)
datos_limpios4
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
#Guardamos el archivo como excel
datos_limpios4.to_excel("data_clean4 - Gastos y costos 2022.xlsx")
